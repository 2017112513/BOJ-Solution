# %%
a,b,v=map(int,input().split())
a=a-b
v=v-b
re=v//a

print(re if re*a==v else re+1)
# Out:
# 2 0 5
# 3

# %%
차 홀 v 홀 2 1 5 : (2>1)>(3>2)>(5>4)>6 
차 짝 v 홀 3 1 7 : (3>2)>(5>4)>7 : v//a +1
차 홀 v 짝 
차 짝 v 짝
# Out:
# 100000000

# %%
205
