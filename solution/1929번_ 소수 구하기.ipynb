# %%
def prime(n):
  if n==1:
    return False
  if n==2:
    return True
  else:
    for i in range(2,int(n**0.5)+1):
      if n%i==0:
        return False
        break
  return True
M,N=map(int,input().split())
for i in range(M,N+1):
  if prime(i)==True:
    print(i)
# Out:
#   File "<ipython-input-1-d89303cd22a7>", line 5
#     else;
#         ^
# SyntaxError: invalid syntax

# %%
M,N=map(int,input().split())
prime=[i for i in range(M,N+1)]
for N in range(M,N+1):
  if N==1:
    prime.remove(N)
  if N!=2 and N%2==0:
    prime.remove(N)
  elif N!=1 and N%2!=0:
    for n in range(2,N):
      if N%n==0:
        prime.remove(N)
        break
print(''.join(prime))
# Out:
# 3 16

# %%
 M,N=map(int,input().split())
prime=set([i for i in range(M,N+1)])
if N==2:
  print(N)
elif N%2==0:
  pass    
else:
  for i in range(2,N):
    if N%i==0:
      break
 M,N=map(int,input().split())

for n in range(M,N+1):
  Prime(n)
# Out:
# 3 16
# 3
# 5
# 7
# 9
# 11
# 13
# 15

# %%
def prime(n):
  if n==1:
    return False
  if n==2:
    return True
  else:
    for i in range(2,int(n**0.5)+1):
      if n%i==0:
        return False
        break
  return True

# %%
M,N=map(int,input().split())
for i in range(M,N+1):
  if prime(i)==True:
    print(i)
# Out:
# 3 16
# 3
# 5
# 7
# 11
# 13
