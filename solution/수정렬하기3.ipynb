# %%
N=int(input())
dic={}
for i in range(N):
  a=int(input())
  try: dic[a]+=1
  except: dic[a]=1
dic = sorted(dic.items(),key=lambda x:x[0])
for key,value in dic:
  for j in range(value):
    print(key,end='\n')
# Out:
# 5
# 1
# 1
# 3
# 2
# 5
# 1
# 1
# 2
# 3
# 5

# %%
3
1
# Out:
# 1

# %%
# Out:
# 5
