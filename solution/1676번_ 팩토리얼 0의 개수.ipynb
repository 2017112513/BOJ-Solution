# %%
def fac(n):
  if n<=0:
    return 1
  else:
    return n*fac(n-1)
n = int(input())
ans = len(str(fac(n)))-len(str(fac(n)).rstrip('0'))
# Out:
# 10

# %%
ans
# Out:
# 2

# %%
str(fac(5)).rstrip('0')
# Out:
# '12'
