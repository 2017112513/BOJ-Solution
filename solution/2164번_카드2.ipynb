# %%
from collections import deque 
N = int(input())
card = deque([i for i in range(1,N+1)])
while len(card)>1:
  card.remove(card[0])
  card.rotate(-1)
print(card[0])
# Out:
# 17
# deque([2])

# %%
card.appendleft(3)

# %%
card.rotate(2)

# %%
card
# Out:
# deque([1, 2, 3])
