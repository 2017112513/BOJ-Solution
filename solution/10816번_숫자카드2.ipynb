# %%
N=int(input())
card=list(map(int,input().split()))
M=int(input())
num=list(map(int,input().split()))
card_n={}
for i in card:
  try: card_n[i]+=1
  except:card_n[i]=1
for i in num:
  try: print(card_n[i],end=' ')
  except: print(0,end=' ')
# Out:
# 10
# 6 3 2 10 10 10 -10 -10 7 3
# 8
# 10 9 -5 2 3 4 5 -10

# %%
from collections import Counter
N=int(input())
card=list(map(int,input().split()))
M=int(input())
num=list(map(int,input().split()))
c = Counter(card)
for i in num:
  try: print(c[i],end=' ')
  except: print(0,end=' ')
# Out:
# 3 0 0 1 2 0 0 2

# %%
# Out:
# 3
