# %%
def fibo(x):
  if x==0:
    a.append(0)
    return 0
    
  elif x==1:
    a.append(1)
    return 1
    
  elif x>=2:
    return fibo(x-1)+fibo(x-2) 
n = int(input())
for i in range(n):
  a=[]
  i=int(input())
  fibo(i)
  print(a.count(0),a.count(1))
# Out:
# 3
# 3
# 1 2
# 4
# 2 3
# 2
# 1 1

# %%
from collections import deque
a=deque()

# %%
a.append(1)

# %%
a.count(1)
# Out:
# 1
