# %%
while 1:
    lis=list(map(int,input().split()))
    lis=sorted(lis)
    if lis.count(0)==3:
             break
    if lis[-1]**2==lis[0]**2+lis[1]**2:
             print('right')
    else:
             print('wrong')
# Out:
# 0 0 0

# %%
lis=list(map(int,input().split())
# Out:
#   File "<ipython-input-3-aa83c2794c30>", line 1
#     lis=list(map(int,input().split())
#                                      ^
# SyntaxError: unexpected EOF while parsing
