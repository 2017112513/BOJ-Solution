# %%
#나머지 + 몫 +1 
print(type('{0:02d}'.format(12)))
# Out:
# <class 'str'>

# %%
T=int(input())
for i in range(T):
    H,W,N=map(int,input().split())
    if N%H==0:
      add=N//H
      floor=H
    else:
      add=N//H+1
      floor=N%H

      
    print(str(floor)+'{0:02d}'.format(add))
# Out:
# 612

# %%
336 12
# Out:
# 10
