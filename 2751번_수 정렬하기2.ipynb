# %%
lis =set()
for _ in range(int(input())):
  lis.add(int(input()))
lis= list(lis)
for i in range(len(lis)):
  print(sorted(lis)[i])
# Out:
# 5
# 2
# 5
# 9
# 83
# 32
# 2
# 5
# 9
# 32
# 83

# %%
a=set()
a.add(2)
a.add(5)
a.add(83)
a.add(9)
a.add(32)

# %%
a={1,2,3,4,5}

# %%
list(a)
# Out:
# [1, 2, 3, 4, 5]
