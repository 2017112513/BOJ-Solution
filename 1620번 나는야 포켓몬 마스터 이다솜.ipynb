# %%
n,m = map(int,input().split())
dic={}
lis=[]
for  i in range(n):
    a=input()
    dic[a]=i+1
    lis.append(a)
for _ in range(m):
    d = input()
    if d.isdigit():
        d = int(d)
        print(lis[d-1])
    else:
        print(dic[d])
# Out:
# 26 5
# Bulbasaur
# Ivysaur
# Venusaur
# Charmander
# Charmeleon
# Charizard
# Squirtle
# Wartortle
# Blastoise
# Caterpie
# Metapod
# Butterfree
# Weedle
# Kakuna
# Beedrill
# Pidgey
# Pidgeotto
# Pidgeot
# Rattata
# Raticate
# Spearow
# Fearow
# Ekans
# Arbok
# Pikachu
# Raichu
# Pikachu
# 25
# 26
# Raichu
# Venusaur
# 3
# Pidgey
# 16
# Kakuna
# 14

# %%
lis
# Out:
# ['Bulbasaur',
#  'Ivysaur',
#  'Venusaur',
#  'Charmander',
#  'Charmeleon',
#  'Charizard',
#  'Squirtle',
#  'Wartortle',
#  'Blastoise',
#  'Caterpie',
#  'Metapod',
#  'Butterfree',
#  'Weedle',
#  'Kakuna',
#  'Beedrill',
#  'Pidgey',
#  'Pidgeotto',
#  'Pidgeot',
#  'Rattata',
#  'Raticate',
#  'Spearow',
#  'Fearow',
#  'Ekans',
#  'Arbok',
#  'Pikachu',
#  'Raichu']
