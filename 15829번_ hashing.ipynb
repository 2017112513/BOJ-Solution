# %%
from string import ascii_lowercase
n=int(input())
s=input()
dic={}
alpha = list(ascii_lowercase)
sum=0
for i in range(len(s)):
  sum= sum+ (alpha.index(s[i])+1)*(31**i)
print(sum)
# Out:
# 3
# zzz
# 25818

# %%
alpha.index('z')
# Out:
# 25

# %%
sum=0
for i in range(len(s)):
  sum= sum+ dic[s[i]]*(31**i)

# %%
sum
# Out:
# 25818
